# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/Deeplearning/blob/main/YOLO_Algorithm_in_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import pandas as pd
import numpy as np
from sklearn import linear_model
from google.colab import drive
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize']=(20,10)
from scipy import stats
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow import keras
import os
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import PIL
import tensorflow_datasets as tfds

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/py-master/DeepLearningML/18_transfer_learning/'
# Out:
# cnn_transfer_learning.ipynb  goldfish.jpg  ImageNetLabels.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***FOLLOW THESE 12 STEPS TO TRAIN AN OBJECT DETECTOR USING YOLOv4***
# NOTE: If you get disconnected or lose your session for some reason you have to run steps 2, 5, and 6 again to mount the drive, edit makefile and build darknet every single time, otherwise the darknet executable will not work.
#
# 1) Create yolov4 and training folders in your drive
# Create a folder named yolov4 in your drive.
#
# Next, create another folder named training inside the yolov4 folder. This is where we will save our trained weights (This path is mentioned in the obj.data file which we will upload later)

# %% [markdown]
# # ***2) Mount drive, link your folder and navigate to /mydrive/yolov4 folder***

# %%
#Navigate to /content/drive/MyDrive/py-master/DeepLearningML/18_transfer_learning/
# %cd /content/drive/MyDrive/py-master/DeepLearningML/18_transfer_learning/yolov4
# Out:
# /content/drive/MyDrive/py-master/DeepLearningML/18_transfer_learning/yolov4

# %%
# check whether GPU is provided
import os
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# # ***3) Clone darknet git repository***

# %%
# !git clone https://github.com/AlexeyAB/darknet
